# %% [markdown]
# # DBSCAN
#
# ![B07030_11_13.jpg](attachment:B07030_11_13.jpg)

# %%
from sklearn.cluster import AgglomerativeClustering, KMeans, DBSCAN
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Bharani Kumar\Desktop\Data Science using Python & R\Version 2 slides\Datasets\Dbscan.csv')
df
# Out:
#              x         y
# 0    -0.803739 -0.853053
# 1     0.852851  0.367618
# 2     0.927180 -0.274902
# 3    -0.752626 -0.511565
# 4     0.706846  0.810679
# ...        ...       ...
# 1095  0.956063 -2.473828
# 1096  0.930758 -2.366531
# 1097  0.989555 -2.475225
# 1098  0.979200 -2.637578
# 1099  1.121931 -2.619054
#
# [1100 rows x 2 columns]

# %%
plt.scatter(df.x, df.y)
plt.show()

# %%
# Generate clusters using Agglomerative Hierarchical Clustering

ac = AgglomerativeClustering(4, linkage = 'average')
ac_clusters = ac.fit_predict(df)

# %%
plt.title("Clusters from Agglomerative Clustering")
plt.scatter(df.x, df.y, c = ac_clusters, s = 50, cmap = 'tab20b')
plt.show()

# %%
# Generate clusters from K-Means

km = KMeans(4)
km_clusters = km.fit_predict(df)

# %%
plt.title("Clusters from K-Means")
plt.scatter(df.x, df.y, c = km_clusters, s = 50, cmap = 'tab20b')
plt.show()

# %%
db = DBSCAN(eps = 0.2, min_samples = 11).fit(df)

# %%
labels = db.labels_
labels
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
plt.scatter(df.x, df.y, c = labels)
plt.title("DBSCAN from Scratch Performance")
plt.show()
